# %% [markdown]
# # Central Limit Theorem (CLT):

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# Generate random numbers :

pop_data=[np.random.randint(10,100) for i in range(10000)]  # population data 

len(pop_data)
# Out:
# 10000

# %%
# Convert into dataframe :

pop_table=pd.DataFrame({"pop_table":pop_data})
pop_table
# Out:
#       pop_table
# 0            47
# 1            11
# 2            33
# 3            19
# 4            30
# ...         ...
# 9995         16
# 9996         25
# 9997         27
# 9998         60
# 9999         12
#
# [10000 rows x 1 columns]

# %%
# Diagram to check distribution :

plt.figure(figsize=(5,3))
sns.kdeplot(x='pop_table',data=pop_table)
# Out:
# <Axes: xlabel='pop_table', ylabel='Density'>

# %%
# Now make sample  from population data to check normal distribution : not more then 10% of data and 
# pick more than  30 samples 

sample_mean=[]
for no_sample in range(50):
    sample_data =[]
    for data in range(500):
         sample_data.append(np.random.choice(pop_data))
    sample_mean.append(np.mean(sample_data))

# %%
# convert into dataframe :

sample_m=pd.DataFrame({"sample_Mean":sample_mean})

# %%
# graph :

sns.kdeplot(x="sample_Mean",data=sample_m)
# Out:
# <Axes: xlabel='sample_Mean', ylabel='Density'>

# %%
# now check population and sample mean :

pop_table.mean(), sample_m.mean()
# Out:
# (pop_table    54.2939
#  dtype: float64,
#  sample_Mean    54.375
#  dtype: float64)
